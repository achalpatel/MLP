# %%
#!/usr/bin/env python
# coding: utf-8

import numpy as np
import pandas as pd
import random
import math

from pandas.core.frame import DataFrame


class Node:
    def __init__(self):
        self.inEdgeList = []
        self.outEdgeList = []
        self.value = None
        self.delta = None
    
    def addInEdge(self, edge):
        self.inEdgeList.append(edge)
    
    def addOutEdge(self, edge):
        self.outEdgeList.append(edge)

        
class InputNode(Node):
    pass

class OutputNode(Node):
    pass

class HiddenNode(Node):
    pass

class Edge:
    def __init__(self, fromNode, toNode):
        self.fromNode = fromNode
        self.toNode = toNode
        self.weight = None


class Layer:
    def __init__(self):
        self.nodes = []
    
    def addNode(self, node):
        self.nodes.append(node)
    def removeNode(self, node):
        self.nodes.remove(node)

class InputLayer(Layer):
    pass

class OutputLayer(Layer):
    pass

class HiddenLayer(Layer):
    pass

class Utility:
    def logistic(node: Node) -> float:
        sumValue = 0.0
        for edge in node.inEdgeList:            
            sumValue += edge.weight * edge.fromNode.value
        ans = 1/ (1 + math.exp(-sumValue))
        return ans

        

class Graph:
    def __init__(self):
        self.inputLayer = InputLayer()
        self.outputLayer = OutputLayer()
        self.hiddenLayerList = []
        self.nodeList = []
        self.edgeList = []
        self.trainDf = None
        self.testDf = None
        self.maxAttribList = []
        self.minAttribList = []
        self.targetList = []
        self.learningRate = 0.01
    
    def createHiddenLayer(self):
        layer = HiddenLayer()        
        self.hiddenLayerList.append(layer)    
    
    def createInputNode(self):
        node = InputNode()
        self.inputLayer.addNode(node)
        self.nodeList.append(node)
        return node
    
    def createOutputNode(self):
        node = OutputNode()
        self.outputLayer.addNode(node)
        self.nodeList.append(node)
        return node
    
    def createHiddenNode(self, hiddenLayer: HiddenLayer):
        node = HiddenNode()
        hiddenLayer.addNode(node)
        self.nodeList.append(node)
        return node

    def createMultipleInputNodes(self, count : int):        
        for i in range(count):
            self.createInputNode()            

    def createMultipleOutputNodes(self, count : int):        
        for i in range(count):
            self.createOutputNode()            

    def createMultipleHiddenNodes(self, hiddenLayer : HiddenLayer, count : int):        
        for i in range(count):
            self.createHiddenNode(hiddenLayer)

    def connectInputToHidden(self):
        for fromNode in self.inputLayer.nodes:
            for toNode in self.hiddenLayerList[0].nodes:
                edge = Edge(fromNode, toNode)
                self.edgeList.append(edge)
                fromNode.addOutEdge(edge)
                toNode.addInEdge(edge)

    def connectHiddenToOutput(self):
        for fromNode in self.hiddenLayerList[0].nodes:
            for toNode in self.outputLayer.nodes:
                edge = Edge(fromNode, toNode)
                self.edgeList.append(edge)
                fromNode.addOutEdge(edge)
                toNode.addInEdge(edge)
            
    def calculateInitialWeights(self):
        for edge in self.edgeList:
            edge.weight = random.uniform(0, 1/10)
    
    def printEdgeData(self):
        for edge in self.edgeList:
            edge.printData()

    def readDf(self, dataframe : DataFrame):
        # self.trainDf = dataframe
        self.trainDf = dataframe.sample(frac=0.8)
        self.testDf = dataframe.drop(self.trainDf.index)    
        self.trainDf.reset_index(drop=True, inplace=True)
        self.testDf.reset_index(drop=True, inplace=True)     
        # Read Max, Min value of Each column and store in a List                
        for i in range(self.trainDf.shape[1]-1):
            self.maxAttribList.append(pd.DataFrame.max(self.trainDf.iloc[:,[i]]))
            self.minAttribList.append(pd.DataFrame.min(self.trainDf.iloc[:,[i]]))

    def inputLayerFeed(self, row : DataFrame):        
        x = 0
        for node in self.inputLayer.nodes:
            normalized = float((row[x]-self.minAttribList[x])/(self.maxAttribList[x] - self.minAttribList[x]))
            node.value = normalized
            x+=1
        self.targetList = [0] * len(self.outputLayer.nodes)
        self.targetList[row[-1]] = 1        
    
    def softMax(self):
        denominator = self.softMaxDenominator()
        for node in self.outputLayer.nodes:
            node.value = math.exp(node.value)/denominator
            
    def softMaxDenominator(self) -> float:
        denominator = 0.0
        for node in self.outputLayer.nodes:
            denominator += math.exp(node.value)
        return denominator

    def mse(self):
        sumVal = 0.0
        m = len(self.outputLayer.nodes)
        for i in range(m):        
            sumVal += (self.targetList[i] - self.outputLayer.nodes[i].value) ** 2
        ans = sumVal/m
#         print("mse:",ans)
        return ans

    def deltaForOutputLayer(self):
        m = len(self.outputLayer.nodes)
        for i in range(m):
            node = self.outputLayer.nodes[i]
            deltaVal = node.value * (1-node.value) * (self.targetList[i]-node.value)
            node.delta = deltaVal
            
    def deltaForHiddenLayer(self):
        m = len(self.hiddenLayerList[0].nodes)
        for i in range(m):
            node = self.hiddenLayerList[0].nodes[i]
            sumVal = 0.0
            for edge in node.outEdgeList:
                sumVal += edge.toNode.delta * edge.weight
            deltaVal = node.value * (1-node.value) * sumVal
            node.delta = deltaVal

    def updateHiddenToOutputWeights(self):
        m = len(self.hiddenLayerList[0].nodes)
        for i in range(m):
            node = self.hiddenLayerList[0].nodes[i]
            for edge in node.outEdgeList:
                edge.weight += self.learningRate * edge.toNode.delta * node.value
    
    def updateInputToHiddenWeights(self):
        m = len(self.inputLayer.nodes)
        for i in range(m):
            node = self.inputLayer.nodes[i]
            for edge in node.outEdgeList:
                edge.weight += self.learningRate * edge.toNode.delta * node.value
    
    def singlePass(self, rowNumber):
        self.inputLayerFeed(self.trainDf.iloc[rowNumber])
        for layer in self.hiddenLayerList:
            for node in layer.nodes:
                node.value = Utility.logistic(node)
        
        for node in self.outputLayer.nodes:
            node.value = Utility.logistic(node)
        
        self.softMax()
        # self.mse()
        self.deltaForOutputLayer()
        self.deltaForHiddenLayer()
        self.updateHiddenToOutputWeights()
        self.updateInputToHiddenWeights()
        
    def trainDfTest(self):
        rightAnswerCount = 0
        for i in range(self.trainDf.shape[0]):
            self.inputLayerFeed(self.trainDf.iloc[i])
            for layer in self.hiddenLayerList:
                for node in layer.nodes:
                    node.value = Utility.logistic(node)

            for node in self.outputLayer.nodes:
                node.value = Utility.logistic(node)
            
            self.softMax()
            outputList = [node.value for node in self.outputLayer.nodes]
            outputIndex = outputList.index(max(outputList))
            targetIndex = self.targetList.index(max(self.targetList))

            print("------------------------------------------------------")
            print("outputList",outputList)
            print("self.targetList",self.targetList)
            print("Target Index : ", targetIndex)
            print("Output Index:", outputIndex)
            print("Output Difference : ", 1-outputList[outputIndex])
            if outputIndex == targetIndex:
                rightAnswerCount+=1
        print("rightAnswerCount : ",rightAnswerCount, "/Out of : ",self.trainDf.shape[0])

    def runANN(self):
#         print("------------------------------------------------")
#         icount = 0
#         for node in self.inputLayer.nodes:    
#             for edge in node.outEdgeList:
#                 print(icount," input edge weight:",edge.weight)
#                 icount+=1
#         icount = 0
#         print("------------------------------------------------")
#         for node in self.hiddenLayerList[0].nodes:    
#             for edge in node.outEdgeList:
#                 print(icount," hidden edge weight:",edge.weight)
#                 icount+=1
        
        for k in range(30):                                                          
            for i in range(self.trainDf.shape[0]):
                self.singlePass(i)
        
        # Last Pass
#         for i in range(self.trainDf.shape[0]):
#             self.singlePass(i)
#             self.mse()

#         icount = 0
#         print("------------------------------------------------")
#         for node in self.inputLayer.nodes:    
#             for edge in node.outEdgeList:
#                 print(icount,"input edge weight:",edge.weight)
#                 icount+=1
#         icount = 0
#         print("------------------------------------------------")
#         for node in self.hiddenLayerList[0].nodes:    
#             for edge in node.outEdgeList:
#                 print(icount," hidden edge weight:",edge.weight)  
#                 icount+=1

# %%
# from MLPv1 import *
import numpy as np
import pandas as pd
import re

def read_file(filepath) -> list:
    dataset = []        
    with open(filepath) as fp:
        for line in fp:                              
            compiler = re.compile("\d+")
            dataList = compiler.findall(line)                        
            row = list(map(int, dataList[1:]))            
            # print(row)
            dataset.append(row)
    return dataset

def createDataFrame(dataset : list):
    df = pd.DataFrame(dataset, columns=['a1','a2','a3','a4','a5','a6','a7','a8','a9','a10','label'])    
    return df


dataset = read_file("dataset.txt")
df = createDataFrame(dataset)
numberOfInputNodes = 10
numberOfOutputNodes = 8
g = Graph()
g.createHiddenLayer()
g.createMultipleInputNodes(numberOfInputNodes)
g.createMultipleHiddenNodes(g.hiddenLayerList[0], 10)
g.createMultipleOutputNodes(numberOfOutputNodes)

print("Graph total nodes : ",len(g.nodeList))
print("Input Nodes : ", len(g.inputLayer.nodes))
print("Output Nodes : ", len(g.outputLayer.nodes))
print("Hidden Nodes : ", len(g.hiddenLayerList[0].nodes))

g.connectInputToHidden()
g.connectHiddenToOutput()
g.calculateInitialWeights()
g.readDf(df)

# g.singlePass()

# for node in g.inputLayer.nodes:    
#     print("input node value:",node.value)

# print("------------------------------------------------")
# for node in g.hiddenLayerList[0].nodes:    
#     print("hidden node value:",node.value)

# print("------------------------------------------------")
# for node in g.outputLayer.nodes:    
#     print("output node value:",node.value)

# g.updateHiddenToOutputWeights()
# g.updateInputToHiddenWeights()
# g.singlePass()
# print("------------------------------------------------")
# for node in g.inputLayer.nodes:    
#     print("input node value:",node.value)

# print("------------------------------------------------")
# for node in g.hiddenLayerList[0].nodes:    
#     print("hidden node value:",node.value)

# print("------------------------------------------------")
# for node in g.outputLayer.nodes:    
#     print("output node value:",node.value)
# Out:
# Graph total nodes :  28
# Input Nodes :  10
# Output Nodes :  8
# Hidden Nodes :  10

# %%
g.trainDfTest()
# Out:
# ------------------------------------------------------
# outputList [0.12426559841954007, 0.126332363743896, 0.12464868236155782, 0.12629129790709237, 0.12521142929525164, 0.12460767148939922, 0.12454283668524703, 0.12410012009801592]
# self.targetList [0, 0, 0, 0, 0, 0, 1, 0]
# Target Index :  6
# Output Index: 1
# Output Difference :  0.873667636256104
# ------------------------------------------------------
# outputList [0.12420919349787096, 0.12641165691298908, 0.12461996446423287, 0.1263081603954441, 0.1252440742745694, 0.12456708716761346, 0.12457064720828719, 0.12406921607899297]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 1
# Output Difference :  0.8735883430870109
# ------------------------------------------------------
# outputList [0.12425934380768315, 0.12636050726565648, 0.12462978200753339, 0.12628012996236138, 0.12522714061417897, 0.12458832067432761, 0.12457009841438853, 0.12408467725387062]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 1
# Output Difference :  0.8736394927343435
# ------------------------------------------------------
# outputList [0.12429231463821959, 0.12630753220259539, 0.12463059951579235, 0.12623057938631227, 0.1252441341813038, 0.12457400029656197, 0.12462064910272376, 0.12410019067649074]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 1
# Output Difference :  0.8736924677974046
# ------------------------------------------------------
# outputList [0.12421366690460672, 0.1263780286049705, 0.12464105535064565, 0.12628304973546375, 0.12522422743995293, 0.12456526625310867, 0.12459401438420885, 0.12410069132704286]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 1
# Output Difference :  0.8736219713950295
# ------------------------------------------------------
# outputList [0.12422493872204333, 0.12637180267122708, 0.12462032663100193, 0.1262830717246009, 0.12526374280498323, 0.1245609402781122, 0.12460107117595587, 0.12407410599207545]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 1
# Output Difference :  0.873628197328773
# ------------------------------------------------------
# outputList [0.1242708983433769, 0.12630094377390613, 0.12462722053145263, 0.1262710120599092, 0.12525449840965003, 0.12459972294686078, 0.12458722184121752, 0.12408848209362673]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 1
# Output Difference :  0.8736990562260939
# ------------------------------------------------------
# outputList [0.12424529413385185, 0.12638704931903816, 0.12462143350161503, 0.12628198418394884, 0.1252334212659997, 0.12456554028214323, 0.12460389783557277, 0.1240613794778304]
# self.targetList [0, 1, 0, 0, 0, 0, 0, 0]
# Target Index :  1
# Output Index: 1
# Output Difference :  0.8736129506809618
# ------------------------------------------------------
# outputList [0.12428009063690493, 0.1263003371886677, 0.1246310903103542, 0.1262320414084368, 0.12524406882008476, 0.1245867119861032, 0.12460988361993253, 0.12411577602951587]
# self.targetList [0, 0, 0, 0, 0, 0, 0, 1]
# Target Index :  7
# Output Index: 1
# Output Difference :  0.8736996628113323
# ------------------------------------------------------
# outputList [0.12423637534554251, 0.12636665053098145, 0.12465126305913414, 0.1262885500903121, 0.12520562736119847, 0.12458611034116263, 0.12456530022199357, 0.12410012304967513]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 1
# Output Difference :  0.8736333494690185
# ------------------------------------------------------
# outputList [0.12420878858820945, 0.12638415158379807, 0.12461470029262546, 0.12629137872157895, 0.12527635346083252, 0.12455781420019417, 0.1245940375002526, 0.12407277565250886]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 1
# Output Difference :  0.873615848416202
# ------------------------------------------------------
# outputList [0.12430913125312675, 0.12631982013413373, 0.12463015599041209, 0.12621804895192265, 0.12520445192634935, 0.12460960009104557, 0.12460577040371079, 0.1241030212492991]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 1
# Output Difference :  0.8736801798658662
# ------------------------------------------------------
# outputList [0.12422436730126264, 0.1263897021058636, 0.12463832731232403, 0.12627360986667266, 0.1252233581776394, 0.12454494125086195, 0.12460970769136707, 0.12409598629400853]
# self.targetList [1, 0, 0, 0, 0, 0, 0, 0]
# Target Index :  0
# Output Index: 1
# Output Difference :  0.8736102978941365
# ------------------------------------------------------
# outputList [0.12424171428019237, 0.12632281039506085, 0.12463548528704664, 0.12629764795889817, 0.12526239695327684, 0.12456830986100836, 0.12458470138999508, 0.12408693387452177]
# self.targetList [0, 0, 0, 0, 1, 0, 0, 0]
# Target Index :  4
# Output Index: 1
# Output Difference :  0.8736771896049391
# ------------------------------------------------------
# outputList [0.12424620605377242, 0.12639236231967252, 0.12464002323687595, 0.1262624635096518, 0.1252029045646961, 0.12456957313322588, 0.12458231046217151, 0.12410415671993393]
# self.targetList [0, 0, 0, 0, 0, 0, 1, 0]
# Target Index :  6
# Output Index: 1
# Output Difference :  0.8736076376803275
# ------------------------------------------------------
# outputList [0.12422628238616679, 0.1263902348921039, 0.12464661909434906, 0.12628342051011757, 0.1252203268358096, 0.12455353371538942, 0.12457982438370527, 0.1240997581823585]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 1
# Output Difference :  0.8736097651078961
# ------------------------------------------------------
# outputList [0.12425485217741551, 0.12636072969781403, 0.12466868711032658, 0.12628910383743439, 0.12519002876047924, 0.12454940156031354, 0.12458165542677617, 0.12410554142944047]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 1
# Output Difference :  0.873639270302186
# ------------------------------------------------------
# outputList [0.1242734754503482, 0.12634046313383004, 0.12462858742356288, 0.12626156133633082, 0.1252288182118528, 0.12459937177711222, 0.12458153489278093, 0.12408618777418212]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 1
# Output Difference :  0.8736595368661699
# ------------------------------------------------------
# outputList [0.12423556472687604, 0.1263643623685334, 0.12463955437703853, 0.1262701342561083, 0.12522126035401054, 0.12457964531535723, 0.12458169284257387, 0.12410778575950214]
# self.targetList [0, 0, 0, 0, 1, 0, 0, 0]
# Target Index :  4
# Output Index: 1
# Output Difference :  0.8736356376314666
# ------------------------------------------------------
# outputList [0.12421155333633808, 0.12638464830322116, 0.12462197056078868, 0.12628750358527951, 0.12525211934643485, 0.12455506804057327, 0.12460748397358137, 0.12407965285378308]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 1
# Output Difference :  0.8736153516967788
# ------------------------------------------------------
# outputList [0.12423230613752867, 0.1263697611476249, 0.12464983373858649, 0.12629060945120654, 0.12520882529577193, 0.12458529685178162, 0.12456357814084068, 0.12409978923665903]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 1
# Output Difference :  0.8736302388523751
# ------------------------------------------------------
# outputList [0.124268480013466, 0.1263301754993583, 0.12464968002061837, 0.12628986230443484, 0.12520917290921674, 0.12460825292293104, 0.1245440375229553, 0.12410033880701934]
# self.targetList [0, 0, 0, 0, 0, 0, 1, 0]
# Target Index :  6
# Output Index: 1
# Output Difference :  0.8736698245006417
# ------------------------------------------------------
# outputList [0.12415522255776888, 0.12640772031148445, 0.12462520516266926, 0.12631487020406065, 0.12527550840059629, 0.12453149534950476, 0.12460061189308502, 0.1240893661208307]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 1
# Output Difference :  0.8735922796885156
# ------------------------------------------------------
# outputList [0.12418636173631811, 0.12642885839461626, 0.12463642317506055, 0.12630809815458074, 0.12523530868160948, 0.12453334599034771, 0.12458583312483971, 0.12408577074262755]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 1
# Output Difference :  0.8735711416053837
# ------------------------------------------------------
# outputList [0.12421058580839886, 0.12641024822263572, 0.12464501286751319, 0.12629541786286994, 0.12521623667237905, 0.12453797695242537, 0.12459654418638538, 0.12408797742739253]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 1
# Output Difference :  0.8735897517773643
# ------------------------------------------------------
# outputList [0.12426729264413063, 0.12632422726352532, 0.12463042571049056, 0.12623904889987797, 0.1252370264358886, 0.12458192327749627, 0.12460582211096391, 0.1241142336576268]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 1
# Output Difference :  0.8736757727364747
# ------------------------------------------------------
# outputList [0.12422419097511672, 0.1264280391126156, 0.12463362430611015, 0.12628686905864472, 0.12520727486359673, 0.12456108546107583, 0.12458268098780974, 0.12407623523503042]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 1
# Output Difference :  0.8735719608873844
# ------------------------------------------------------
# outputList [0.12429792413198179, 0.1262953710470373, 0.12462638437418527, 0.12624682289402403, 0.12523196171112705, 0.12461844599774242, 0.12459037954495154, 0.12409271029895066]
# self.targetList [0, 1, 0, 0, 0, 0, 0, 0]
# Target Index :  1
# Output Index: 1
# Output Difference :  0.8737046289529626
# ------------------------------------------------------
# outputList [0.12427071918853287, 0.12630339803427418, 0.12464451272327949, 0.12628300535508766, 0.12524710287120305, 0.12457853670249429, 0.1245780361702377, 0.12409468895489068]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 1
# Output Difference :  0.8736966019657258
# ------------------------------------------------------
# outputList [0.1242444159703486, 0.1263848328271858, 0.12463224521948776, 0.12629018124087768, 0.12521647853787204, 0.12457403067784463, 0.12458574870413089, 0.12407206682225268]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 1
# Output Difference :  0.8736151671728142
# ------------------------------------------------------
# outputList [0.1242436649523733, 0.12640351439061404, 0.12462603836342151, 0.12627003511954468, 0.12521347441844224, 0.12455570503109321, 0.12461051843420747, 0.12407704929030348]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 1
# Output Difference :  0.873596485609386
# ------------------------------------------------------
# outputList [0.12421897071277752, 0.1264128905127875, 0.12465816833425303, 0.126287103241054, 0.12519926169096618, 0.12455099372343895, 0.12456490358558528, 0.12410770819913766]
# self.targetList [0, 1, 0, 0, 0, 0, 0, 0]
# Target Index :  1
# Output Index: 1
# Output Difference :  0.8735871094872125
# ------------------------------------------------------
# outputList [0.12419865736688628, 0.12640733900227297, 0.12462038774329508, 0.1262699852888814, 0.12525802696914765, 0.12453394305756285, 0.12462492656935074, 0.12408673400260303]
# self.targetList [0, 1, 0, 0, 0, 0, 0, 0]
# Target Index :  1
# Output Index: 1
# Output Difference :  0.873592660997727
# ------------------------------------------------------
# outputList [0.12428238321640978, 0.12631505671979992, 0.12462724713952548, 0.1262356183642427, 0.12525180434248062, 0.12457204917004623, 0.12461635630190153, 0.12409948474559374]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 1
# Output Difference :  0.8736849432802001
# ------------------------------------------------------
# outputList [0.12420202240680295, 0.12640148716728403, 0.12461738555583679, 0.1262671252518166, 0.12525722684621246, 0.12454451292965055, 0.12462098656489147, 0.12408925327750513]
# self.targetList [0, 1, 0, 0, 0, 0, 0, 0]
# Target Index :  1
# Output Index: 1
# Output Difference :  0.873598512832716
# ------------------------------------------------------
# outputList [0.12425017470904609, 0.12638333454444625, 0.12462312033377304, 0.1262794833641174, 0.1252296181557088, 0.12456649703310622, 0.1246060104924038, 0.12406176136739848]
# self.targetList [0, 1, 0, 0, 0, 0, 0, 0]
# Target Index :  1
# Output Index: 1
# Output Difference :  0.8736166654555537
# ------------------------------------------------------
# outputList [0.12423428269821497, 0.12636672546271474, 0.12463574346208282, 0.12626836844908546, 0.1252450698452168, 0.12454072832484753, 0.12461427986622615, 0.12409480189161153]
# self.targetList [0, 0, 0, 0, 1, 0, 0, 0]
# Target Index :  4
# Output Index: 1
# Output Difference :  0.8736332745372852
# ------------------------------------------------------
# outputList [0.12424115717829291, 0.12636214016952818, 0.12464265410189536, 0.12626616330626336, 0.12523117375782478, 0.12456481421345224, 0.12459154207455007, 0.12410035519819307]
# self.targetList [0, 0, 0, 0, 1, 0, 0, 0]
# Target Index :  4
# Output Index: 1
# Output Difference :  0.8736378598304718
# ------------------------------------------------------
# outputList [0.12423152403645353, 0.12634429140178782, 0.12462903164762204, 0.12627583810790902, 0.1252624744132426, 0.12456099040722347, 0.12460385584663862, 0.12409199413912277]
# self.targetList [0, 0, 0, 0, 1, 0, 0, 0]
# Target Index :  4
# Output Index: 1
# Output Difference :  0.8736557085982122
# ------------------------------------------------------
# outputList [0.12421204351791595, 0.12637255217692925, 0.12461748739224873, 0.1263212310253189, 0.12527867142005578, 0.12455650282151949, 0.1245889375573238, 0.12405257408868813]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 1
# Output Difference :  0.8736274478230708
# ------------------------------------------------------
# outputList [0.12423009149485313, 0.1263704412467247, 0.12462838455790301, 0.12627790879667336, 0.12523767383664813, 0.12455866040831856, 0.12461568200034702, 0.12408115765853196]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 1
# Output Difference :  0.8736295587532753
# ------------------------------------------------------
# outputList [0.12425154850348874, 0.12636640447492695, 0.12462709804164285, 0.12628405667993564, 0.1252332330985972, 0.12458677354880165, 0.1245668013050057, 0.12408408434760118]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 1
# Output Difference :  0.873633595525073
# ------------------------------------------------------
# outputList [0.12424136016853655, 0.12634526198718404, 0.12464417199257116, 0.1262542219865367, 0.12522255114202513, 0.12456874991249064, 0.12460696448604447, 0.1241167183246111]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 1
# Output Difference :  0.8736547380128159
# ------------------------------------------------------
# outputList [0.12422179173618775, 0.12641074235319164, 0.12465916670595269, 0.12628565340456852, 0.12519703761111128, 0.12455154492548005, 0.12456610805963726, 0.12410795520387079]
# self.targetList [0, 1, 0, 0, 0, 0, 0, 0]
# Target Index :  1
# Output Index: 1
# Output Difference :  0.8735892576468084
# ------------------------------------------------------
# outputList [0.12420436768113971, 0.12638753301925357, 0.12461316035163093, 0.12629365812883533, 0.12527980515534373, 0.12455696130973862, 0.12459210599843185, 0.12407240835562626]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 1
# Output Difference :  0.8736124669807465
# ------------------------------------------------------
# outputList [0.12428257649675117, 0.12631264745306922, 0.12463558236970308, 0.12623128973695766, 0.12522519934125487, 0.12458493811147281, 0.12461243927149314, 0.12411532721929795]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 1
# Output Difference :  0.8736873525469308
# ------------------------------------------------------
# outputList [0.12424915646717628, 0.12636713350368084, 0.12463842519283416, 0.12626227806802584, 0.12522881890961676, 0.12455892493292184, 0.12459925887485208, 0.12409600405089226]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 1
# Output Difference :  0.8736328664963191
# ------------------------------------------------------
# outputList [0.1242182733647344, 0.12638573688760288, 0.12464573011459261, 0.12632635298901398, 0.1252103073217349, 0.12457723728777174, 0.12455049500915921, 0.12408586702539023]
# self.targetList [0, 0, 0, 0, 0, 0, 0, 1]
# Target Index :  7
# Output Index: 1
# Output Difference :  0.8736142631123971
# ------------------------------------------------------
# outputList [0.1242021041572144, 0.12640590870374166, 0.1246376660649866, 0.12632171015822694, 0.12522478376371482, 0.1245669895763852, 0.12455879429886187, 0.12408204327686853]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 1
# Output Difference :  0.8735940912962583
# ------------------------------------------------------
# outputList [0.1242314594633555, 0.12634067438107222, 0.12463662000837399, 0.12625172069877277, 0.12524886056653456, 0.12455428119479665, 0.12462602547576526, 0.12411035821132893]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 1
# Output Difference :  0.8736593256189278
# ------------------------------------------------------
# outputList [0.12422499672469567, 0.12642742756411438, 0.12463390815869776, 0.12628645289699167, 0.12520663976156665, 0.12456124301683413, 0.12458302696015659, 0.12407630491694313]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 1
# Output Difference :  0.8735725724358856
# ------------------------------------------------------
# outputList [0.1242983302769778, 0.1262937951883466, 0.1246332381456435, 0.12623944278401972, 0.12522948675374146, 0.12460273247169981, 0.1246006203086404, 0.12410235407093069]
# self.targetList [0, 0, 0, 0, 0, 0, 1, 0]
# Target Index :  6
# Output Index: 1
# Output Difference :  0.8737062048116534
# ------------------------------------------------------
# outputList [0.12421333604693706, 0.1263895375911834, 0.12462018587994494, 0.1262821446316389, 0.1252414930936243, 0.1245682346503131, 0.12459867503714517, 0.12408639306921332]
# self.targetList [0, 0, 0, 0, 1, 0, 0, 0]
# Target Index :  4
# Output Index: 1
# Output Difference :  0.8736104624088166
# ------------------------------------------------------
# outputList [0.12427902033647037, 0.1263044609956516, 0.12463290850981676, 0.1262651090738069, 0.1252469699536821, 0.12458368837003343, 0.12459705762810798, 0.12409078513243094]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 1
# Output Difference :  0.8736955390043484
# ------------------------------------------------------
# outputList [0.12424008446260071, 0.126364610193631, 0.1246017125171596, 0.12627447846251588, 0.12527075935789675, 0.12458916375437946, 0.1245924481969566, 0.12406674305486008]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 1
# Output Difference :  0.873635389806369
# ------------------------------------------------------
# outputList [0.12421494604267207, 0.12643505615111697, 0.1246303671494398, 0.12629164957760083, 0.1252145624658147, 0.12455928019861015, 0.1245787065406773, 0.12407543187406797]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 1
# Output Difference :  0.8735649438488831
# ------------------------------------------------------
# outputList [0.12423765052695979, 0.1263404602207669, 0.1246339627691654, 0.12626461825130958, 0.12524487862333078, 0.12457405409325582, 0.12460038821937604, 0.12410398729583577]
# self.targetList [0, 0, 0, 0, 0, 0, 0, 1]
# Target Index :  7
# Output Index: 1
# Output Difference :  0.873659539779233
# ------------------------------------------------------
# outputList [0.12420850324274318, 0.126411737908762, 0.12463536403773033, 0.1262985105879749, 0.12522739117025194, 0.12455209556756114, 0.12458269958353968, 0.12408369790143678]
# self.targetList [0, 0, 0, 0, 1, 0, 0, 0]
# Target Index :  4
# Output Index: 1
# Output Difference :  0.873588262091238
# ------------------------------------------------------
# outputList [0.12424103076328814, 0.126373312158029, 0.12463563259323422, 0.12626645317603488, 0.1252351390185197, 0.1245573452560079, 0.12459572158028981, 0.12409536545459639]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 1
# Output Difference :  0.873626687841971
# ------------------------------------------------------
# outputList [0.12422455780258307, 0.12634615922073425, 0.12465999875747993, 0.1262882799743036, 0.12522057753769403, 0.12455847847381722, 0.12458931868365987, 0.12411262954972807]
# self.targetList [0, 1, 0, 0, 0, 0, 0, 0]
# Target Index :  1
# Output Index: 1
# Output Difference :  0.8736538407792658
# ------------------------------------------------------
# outputList [0.12421498665349157, 0.12640686951391567, 0.12464657380083924, 0.12629312467624496, 0.12521277087923435, 0.12453882287555214, 0.12459847872520705, 0.1240883728755151]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 1
# Output Difference :  0.8735931304860843
# ------------------------------------------------------
# outputList [0.12423586845583759, 0.1263913398634676, 0.12462926638652799, 0.1262945340928219, 0.12522317408494313, 0.1245723411188471, 0.12458209327061748, 0.12407138272693731]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 1
# Output Difference :  0.8736086601365324
# ------------------------------------------------------
# outputList [0.12426346651278318, 0.12634688325527899, 0.12460967323865874, 0.12626262902020963, 0.12525261503081053, 0.12459379014344679, 0.12460249204301801, 0.12406845075579422]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 1
# Output Difference :  0.873653116744721
# ------------------------------------------------------
# outputList [0.12427143513072313, 0.1263154436875016, 0.12461744035189802, 0.12626013031239058, 0.12525245858398584, 0.12461314248799553, 0.12457908662526845, 0.12409086282023686]
# self.targetList [0, 1, 0, 0, 0, 0, 0, 0]
# Target Index :  1
# Output Index: 1
# Output Difference :  0.8736845563124984
# ------------------------------------------------------
# outputList [0.12421704517879881, 0.12641391248353293, 0.12464688823405605, 0.12627773130659356, 0.12520536134556043, 0.12453388262560329, 0.12461498430296847, 0.12409019452288658]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 1
# Output Difference :  0.873586087516467
# ------------------------------------------------------
# outputList [0.1242234174767682, 0.12633684591840852, 0.12462913486506558, 0.1263069274809003, 0.1252766522488379, 0.12456472663821476, 0.12457680498221312, 0.1240854903895918]
# self.targetList [0, 0, 0, 0, 1, 0, 0, 0]
# Target Index :  4
# Output Index: 1
# Output Difference :  0.8736631540815915
# ------------------------------------------------------
# outputList [0.12425916164297249, 0.12634328060720756, 0.12460413840258465, 0.12626240125369795, 0.12525350341580238, 0.12461670184750369, 0.1245797235444306, 0.12408108928580083]
# self.targetList [0, 0, 0, 0, 0, 0, 1, 0]
# Target Index :  6
# Output Index: 1
# Output Difference :  0.8736567193927924
# ------------------------------------------------------
# outputList [0.12422506723000973, 0.12639116107003653, 0.12464619304116695, 0.12628404368007332, 0.12522128040572775, 0.12455329698148046, 0.12457930150845936, 0.12409965608304582]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 1
# Output Difference :  0.8736088389299634
# ------------------------------------------------------
# outputList [0.12422715590950559, 0.12638088984806328, 0.12461391207635793, 0.1262866672814487, 0.12525578406326465, 0.12458078598909465, 0.12457986710147442, 0.1240749377307907]
# self.targetList [0, 0, 0, 0, 0, 0, 1, 0]
# Target Index :  6
# Output Index: 1
# Output Difference :  0.8736191101519367
# ------------------------------------------------------
# outputList [0.12427458798205487, 0.12632781046670324, 0.12462331010934015, 0.1262572777665376, 0.1252363349942602, 0.12460783655834651, 0.12458196723125775, 0.1240908748914997]
# self.targetList [1, 0, 0, 0, 0, 0, 0, 0]
# Target Index :  0
# Output Index: 1
# Output Difference :  0.8736721895332967
# ------------------------------------------------------
# outputList [0.12429416177547545, 0.1263311148045357, 0.12462512311584228, 0.1262256008654801, 0.12521602887992234, 0.1246066131488612, 0.1245993706517278, 0.12410198675815523]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 1
# Output Difference :  0.8736688851954643
# ------------------------------------------------------
# outputList [0.124241634551628, 0.12640505304249683, 0.12462533905947039, 0.12627108250977734, 0.1252150606179973, 0.12455531059020888, 0.12460963180755943, 0.12407688782086206]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 1
# Output Difference :  0.8735949469575032
# ------------------------------------------------------
# outputList [0.1242148602378857, 0.12635704130000588, 0.12462326428572902, 0.1262843661813765, 0.12527545583200483, 0.1245577534333235, 0.12459659166289565, 0.12409066706677879]
# self.targetList [0, 0, 0, 0, 1, 0, 0, 0]
# Target Index :  4
# Output Index: 1
# Output Difference :  0.8736429586999941
# ------------------------------------------------------
# outputList [0.12420009826858508, 0.12640789455348198, 0.12463303312197359, 0.1262789475432248, 0.12523687667963013, 0.12454261328560627, 0.1246031851141539, 0.1240973514333443]
# self.targetList [0, 0, 0, 0, 0, 0, 1, 0]
# Target Index :  6
# Output Index: 1
# Output Difference :  0.873592105446518
# ------------------------------------------------------
# outputList [0.12428334345125629, 0.1263512465919, 0.12462820759871863, 0.12622942876681265, 0.12521361589246335, 0.1245879410111467, 0.12460293323725245, 0.12410328345044994]
# self.targetList [0, 0, 0, 0, 1, 0, 0, 0]
# Target Index :  4
# Output Index: 1
# Output Difference :  0.8736487534081
# ------------------------------------------------------
# outputList [0.12421490130747381, 0.12637334835844385, 0.1246377731195879, 0.12628138304212114, 0.12525379698594896, 0.12454394309411314, 0.12460088719239215, 0.1240939668999191]
# self.targetList [0, 0, 0, 0, 0, 0, 1, 0]
# Target Index :  6
# Output Index: 1
# Output Difference :  0.8736266516415562
# ------------------------------------------------------
# outputList [0.12427201579843819, 0.12633851832934412, 0.12466233946465417, 0.12627665845943323, 0.12518707018525466, 0.12458649248186532, 0.12456009890579059, 0.12411680637521966]
# self.targetList [0, 0, 0, 0, 1, 0, 0, 0]
# Target Index :  4
# Output Index: 1
# Output Difference :  0.8736614816706558
# ------------------------------------------------------
# outputList [0.12416386251311293, 0.12640099802547827, 0.12462826884946533, 0.1263103030609537, 0.12526873108687808, 0.12453312557853384, 0.12460454364023474, 0.12409016724534318]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 1
# Output Difference :  0.8735990019745217
# ------------------------------------------------------
# outputList [0.12426866760039296, 0.12630496460554558, 0.12464380681147098, 0.12628403968934623, 0.12524869639121372, 0.1245781315248752, 0.12457715926847479, 0.12409453410868053]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 1
# Output Difference :  0.8736950353944544
# ------------------------------------------------------
# outputList [0.12426633400537243, 0.12635521876657627, 0.12463218774266266, 0.1262766102375779, 0.1252216795155538, 0.12458970915725971, 0.12457305438150718, 0.12408520619348994]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 1
# Output Difference :  0.8736447812334237
# rightAnswerCount :  9 /Out of :  80

# %%
g.runANN()

# %%
g.trainDfTest()
# Out:
# ------------------------------------------------------
# outputList [0.1038412965936717, 0.12224716135883507, 0.14052894665223414, 0.15236020278859694, 0.1269039214909546, 0.1304243892028312, 0.11793059194172657, 0.10576348997114977]
# self.targetList [0, 0, 0, 0, 0, 0, 1, 0]
# Target Index :  6
# Output Index: 3
# Output Difference :  0.847639797211403
# ------------------------------------------------------
# outputList [0.10287704220731407, 0.12215399914108156, 0.14124505346540825, 0.15344278005663498, 0.12704553164133603, 0.1306936246843261, 0.11764842169114666, 0.10489354711275242]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 3
# Output Difference :  0.8465572199433651
# ------------------------------------------------------
# outputList [0.10372430184105937, 0.12225187157860815, 0.14060206404065836, 0.15248333537993586, 0.12693127246336594, 0.1304424667677904, 0.11791628707303192, 0.10564840085554994]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 3
# Output Difference :  0.8475166646200641
# ------------------------------------------------------
# outputList [0.10458888727453597, 0.12235702861976931, 0.13992541330200908, 0.15145181885484268, 0.1268511645129727, 0.13015417843992752, 0.11824302548150134, 0.10642848351444142]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 3
# Output Difference :  0.8485481811451573
# ------------------------------------------------------
# outputList [0.10323491267821687, 0.12218596469683105, 0.14097539719722973, 0.1530166532293081, 0.12698249855399418, 0.13057386559552253, 0.11778680271657516, 0.10524390533232243]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 3
# Output Difference :  0.8469833467706919
# ------------------------------------------------------
# outputList [0.10326327761849065, 0.12218278564695922, 0.14094227651238472, 0.15299036476419808, 0.12701724387574428, 0.13056231115490455, 0.11780005808888513, 0.10524168233843348]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 3
# Output Difference :  0.8470096352358019
# ------------------------------------------------------
# outputList [0.10423497643974566, 0.1222868976286751, 0.1401934743717935, 0.15188567468169664, 0.1269002935092384, 0.13028877037454117, 0.11809970465340185, 0.10611020834090772]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 3
# Output Difference :  0.8481143253183033
# ------------------------------------------------------
# outputList [0.10322487307842707, 0.12219067772333167, 0.14098493168795978, 0.1530562827950187, 0.12699310230546332, 0.13058765218454005, 0.1177845707946137, 0.10517790943064574]
# self.targetList [0, 1, 0, 0, 0, 0, 0, 0]
# Target Index :  1
# Output Index: 3
# Output Difference :  0.8469437172049813
# ------------------------------------------------------
# outputList [0.10480443255811826, 0.12239137403800723, 0.13974334610880124, 0.15118307573813528, 0.12682891418453499, 0.13009183415243802, 0.11830901255159322, 0.10664801066837186]
# self.targetList [0, 0, 0, 0, 0, 0, 0, 1]
# Target Index :  7
# Output Index: 3
# Output Difference :  0.8488169242618647
# ------------------------------------------------------
# outputList [0.10335030150649605, 0.12219502044252181, 0.14090637963195854, 0.15290648045493635, 0.1269523562538987, 0.13056200717577443, 0.11779472793767369, 0.10533272659674042]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 3
# Output Difference :  0.8470935195450636
# ------------------------------------------------------
# outputList [0.10308450309835071, 0.12216397349551042, 0.14107206861523086, 0.15318700686338238, 0.1270501991242326, 0.13061399942537197, 0.1177390877336026, 0.10508916164431849]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 3
# Output Difference :  0.8468129931366176
# ------------------------------------------------------
# outputList [0.10483751291993429, 0.12241533776775979, 0.13973208707911824, 0.15116336707090805, 0.12678499589805445, 0.13011542296413386, 0.11830848635710738, 0.10664278994298391]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 3
# Output Difference :  0.848836632929092
# ------------------------------------------------------
# outputList [0.10321163377321343, 0.12219058871119719, 0.1410013769201643, 0.1530466841014028, 0.12698442818795733, 0.13056425414565626, 0.11778915875173002, 0.10521187540867874]
# self.targetList [1, 0, 0, 0, 0, 0, 0, 0]
# Target Index :  0
# Output Index: 3
# Output Difference :  0.8469533158985972
# ------------------------------------------------------
# outputList [0.10365253249470707, 0.12220389555418644, 0.1406544317501678, 0.15256485412677487, 0.1269749760175841, 0.1304412650897534, 0.11791043612512443, 0.10559760884170181]
# self.targetList [0, 0, 0, 0, 1, 0, 0, 0]
# Target Index :  4
# Output Index: 3
# Output Difference :  0.8474351458732251
# ------------------------------------------------------
# outputList [0.10346879554631253, 0.12223843919235304, 0.14080995619911787, 0.1527553887070039, 0.12693430402253578, 0.13050694160424586, 0.11784602304404142, 0.10544015168438967]
# self.targetList [0, 0, 0, 0, 0, 0, 1, 0]
# Target Index :  6
# Output Index: 3
# Output Difference :  0.8472446112929961
# ------------------------------------------------------
# outputList [0.10318049017472182, 0.12218520993495975, 0.14103727443213604, 0.15308955024106066, 0.12698653973384838, 0.13058244442225697, 0.11775209190990589, 0.10518639915111039]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 3
# Output Difference :  0.8469104497589394
# ------------------------------------------------------
# outputList [0.10328790347750805, 0.12217324951214571, 0.1409915287009011, 0.15300021226250113, 0.12694690211556237, 0.13055105497711425, 0.1177807480920152, 0.10526840086225223]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 3
# Output Difference :  0.8469997877374988
# ------------------------------------------------------
# outputList [0.10402801203506189, 0.1222894974697305, 0.14036080708566565, 0.15212340866440566, 0.12689727209270246, 0.1303587861048454, 0.11802653874741195, 0.10591567780017651]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 3
# Output Difference :  0.8478765913355943
# ------------------------------------------------------
# outputList [0.10367015571621072, 0.12225092780068489, 0.1406356151800594, 0.15251541238847727, 0.12693019368519143, 0.13044654523839652, 0.11791712687626496, 0.10563402311471491]
# self.targetList [0, 0, 0, 0, 1, 0, 0, 0]
# Target Index :  4
# Output Index: 3
# Output Difference :  0.8474845876115227
# ------------------------------------------------------
# outputList [0.10310025631281078, 0.12216882707442546, 0.141065235090216, 0.15317187118152542, 0.12702487162994008, 0.13060837210196724, 0.11775582395846698, 0.10510474265064805]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 3
# Output Difference :  0.8468281288184746
# ------------------------------------------------------
# outputList [0.1033053032596768, 0.12219027213857041, 0.14093898287825984, 0.15295608678178044, 0.12696064379502026, 0.13057492274334465, 0.11777943222175019, 0.1052943561815975]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 3
# Output Difference :  0.8470439132182196
# ------------------------------------------------------
# outputList [0.10387339787431873, 0.12225062904715545, 0.14050574283119827, 0.15232445240160664, 0.12689814616646847, 0.13041531955816507, 0.11794149928467093, 0.10579081283641646]
# self.targetList [0, 0, 0, 0, 0, 0, 1, 0]
# Target Index :  6
# Output Index: 3
# Output Difference :  0.8476755475983934
# ------------------------------------------------------
# outputList [0.10252014434191299, 0.12209053909349447, 0.14150539709135979, 0.153808684344914, 0.12711720956956193, 0.13076562641661235, 0.11757022750488176, 0.10462217163726281]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 3
# Output Difference :  0.846191315655086
# ------------------------------------------------------
# outputList [0.10242004961097957, 0.12209152185741445, 0.14161889142086068, 0.1539448218187719, 0.12709128403912762, 0.13081181750479595, 0.11751647127413464, 0.10450514247391526]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 3
# Output Difference :  0.8460551781812281
# ------------------------------------------------------
# outputList [0.10268524689700716, 0.12211855025268302, 0.14142594935037578, 0.15365714351587126, 0.1270407815909619, 0.1307335960316132, 0.11760682587156096, 0.10473190648992677]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 3
# Output Difference :  0.8463428564841288
# ------------------------------------------------------
# outputList [0.10442100649667482, 0.1223447792521345, 0.14004408866634488, 0.15163404838763012, 0.12686157269544823, 0.13020857328858254, 0.118180353441863, 0.1063055777713219]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 3
# Output Difference :  0.8483659516123698
# ------------------------------------------------------
# outputList [0.10274648230473621, 0.12214524528292574, 0.1413740094724629, 0.15359210650500382, 0.12702313103270094, 0.1307397628244094, 0.11761105088050085, 0.1047682116972603]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 3
# Output Difference :  0.8464078934949961
# ------------------------------------------------------
# outputList [0.10467211840937586, 0.12236261564444587, 0.13985432648071006, 0.15137164301066414, 0.12683030722297556, 0.13017362132813096, 0.11824364155687635, 0.10649172634682132]
# self.targetList [0, 1, 0, 0, 0, 0, 0, 0]
# Target Index :  1
# Output Index: 3
# Output Difference :  0.8486283569893358
# ------------------------------------------------------
# outputList [0.1039305598932903, 0.12223431388029359, 0.1404581391394322, 0.15225257807309842, 0.1269279898575364, 0.13036761554532944, 0.11799088906080249, 0.10583791455021724]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 3
# Output Difference :  0.8477474219269016
# ------------------------------------------------------
# outputList [0.10326469809048083, 0.12219456484542204, 0.14096364282015633, 0.15301787825379934, 0.1269734432913337, 0.13058139481363606, 0.1177802742838669, 0.10522410360130482]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 3
# Output Difference :  0.8469821217462007
# ------------------------------------------------------
# outputList [0.10325250917423126, 0.12221032411743127, 0.1409678240397652, 0.1530144604568402, 0.1269701329228197, 0.1305671690970121, 0.1177988576033258, 0.10521872258857445]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 3
# Output Difference :  0.8469855395431598
# ------------------------------------------------------
# outputList [0.10288839390733452, 0.12215664507191208, 0.1412802949371202, 0.15342185161136512, 0.1270004192375823, 0.1306776657057017, 0.11764454000462228, 0.10493018952436184]
# self.targetList [0, 1, 0, 0, 0, 0, 0, 0]
# Target Index :  1
# Output Index: 3
# Output Difference :  0.8465781483886349
# ------------------------------------------------------
# outputList [0.10305256810724338, 0.12218132199254385, 0.14109503119099004, 0.15320117641118008, 0.12703507636562716, 0.13059983948453233, 0.11775747467785946, 0.10507751177002368]
# self.targetList [0, 1, 0, 0, 0, 0, 0, 0]
# Target Index :  1
# Output Index: 3
# Output Difference :  0.84679882358882
# ------------------------------------------------------
# outputList [0.10447628572216351, 0.12234444520979643, 0.14000670456048409, 0.15157918320654418, 0.12687064937393072, 0.13018548185232515, 0.11820449726563671, 0.10633275280911902]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 3
# Output Difference :  0.8484208167934558
# ------------------------------------------------------
# outputList [0.10315574406290537, 0.12219525405382609, 0.14100981689610964, 0.1530815306288301, 0.1270213523508914, 0.13057627089310975, 0.11778867809073566, 0.10517135302359203]
# self.targetList [0, 1, 0, 0, 0, 0, 0, 0]
# Target Index :  1
# Output Index: 3
# Output Difference :  0.8469184693711699
# ------------------------------------------------------
# outputList [0.10327879763427772, 0.12219636874998745, 0.1409458056348006, 0.15299693687051757, 0.12698317667351672, 0.13057211700947494, 0.11780294741350579, 0.10522385001391908]
# self.targetList [0, 1, 0, 0, 0, 0, 0, 0]
# Target Index :  1
# Output Index: 3
# Output Difference :  0.8470030631294825
# ------------------------------------------------------
# outputList [0.1034786542744311, 0.12221453411604592, 0.14079072137649334, 0.1527394899591399, 0.12697534758272755, 0.13047175655595883, 0.11787946419829544, 0.10545003193690793]
# self.targetList [0, 0, 0, 0, 1, 0, 0, 0]
# Target Index :  4
# Output Index: 3
# Output Difference :  0.8472605100408601
# ------------------------------------------------------
# outputList [0.10353067706520729, 0.12222250683908219, 0.14075644559017939, 0.15268038870386552, 0.1269548403164926, 0.13048146090040152, 0.11787772183002553, 0.10549595875474599]
# self.targetList [0, 0, 0, 0, 1, 0, 0, 0]
# Target Index :  4
# Output Index: 3
# Output Difference :  0.8473196112961345
# ------------------------------------------------------
# outputList [0.1036695184596436, 0.12222825040978966, 0.14062652241061763, 0.15251822835859674, 0.12697083711025522, 0.1304265192454407, 0.11793543909957648, 0.10562468490607996]
# self.targetList [0, 0, 0, 0, 1, 0, 0, 0]
# Target Index :  4
# Output Index: 3
# Output Difference :  0.8474817716414033
# ------------------------------------------------------
# outputList [0.10290449726742422, 0.12212053193022081, 0.14122200496648596, 0.15342492127725246, 0.12707707295204998, 0.1306755082423855, 0.11767290902618596, 0.10490255433799532]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 3
# Output Difference :  0.8465750787227475
# ------------------------------------------------------
# outputList [0.10330617235881806, 0.12219055061674867, 0.1409156395070962, 0.15294513610164115, 0.1269870214254007, 0.1305488657586995, 0.11782618829775604, 0.10528042593383954]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 3
# Output Difference :  0.8470548638983588
# ------------------------------------------------------
# outputList [0.10363765002197453, 0.1222425331557628, 0.14066479098860846, 0.1525795540393942, 0.1269469492131884, 0.13046709967044842, 0.11788679775798942, 0.10557462515263366]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 3
# Output Difference :  0.8474204459606058
# ------------------------------------------------------
# outputList [0.10383262258579357, 0.1222593755480358, 0.14051439027613832, 0.15231996632995168, 0.12691175544506483, 0.13038420419015567, 0.1179905331166894, 0.10578715250817075]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 3
# Output Difference :  0.8476800336700483
# ------------------------------------------------------
# outputList [0.10291933188567792, 0.12215985707819586, 0.141257847940971, 0.15338804391516486, 0.1269946022627583, 0.1306686561984826, 0.11765505039216506, 0.10495661032658453]
# self.targetList [0, 1, 0, 0, 0, 0, 0, 0]
# Target Index :  1
# Output Index: 3
# Output Difference :  0.8466119560848351
# ------------------------------------------------------
# outputList [0.10303561492944867, 0.12215884993917174, 0.14110759033175613, 0.15324065861018152, 0.12705925016582603, 0.13062818748332455, 0.11772241496238982, 0.10504743357790156]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 3
# Output Difference :  0.8467593413898185
# ------------------------------------------------------
# outputList [0.1045943922897202, 0.12236417051830252, 0.13991886568453063, 0.1514379340209349, 0.1268315304543768, 0.13016035703143308, 0.11823969657484588, 0.10645305342585601]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 3
# Output Difference :  0.8485620659790651
# ------------------------------------------------------
# outputList [0.10352795340853997, 0.12222541930316433, 0.1407613474783941, 0.15268804257825672, 0.1269527088967299, 0.13047845997721985, 0.11788124049748978, 0.10548482786020533]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 3
# Output Difference :  0.8473119574217433
# ------------------------------------------------------
# outputList [0.10287434069252273, 0.12212711335954853, 0.14127946674046832, 0.1534710877787532, 0.12701577585093227, 0.13070676001379544, 0.11762615803295881, 0.10489929753102065]
# self.targetList [0, 0, 0, 0, 0, 0, 0, 1]
# Target Index :  7
# Output Index: 3
# Output Difference :  0.8465289122212468
# ------------------------------------------------------
# outputList [0.10265457587081406, 0.12210979528251419, 0.14143897490639368, 0.15370282607186297, 0.12705424356785908, 0.13076795956178297, 0.11756595795116008, 0.10470566678761292]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 3
# Output Difference :  0.8462971739281371
# ------------------------------------------------------
# outputList [0.10380637514753167, 0.12225266097581684, 0.14051961477293368, 0.15233803084568479, 0.12693984628745708, 0.13037651265458255, 0.11800311619600977, 0.10576384311998366]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 3
# Output Difference :  0.8476619691543152
# ------------------------------------------------------
# outputList [0.10275527408026844, 0.12214615214046143, 0.14136762480136278, 0.15358253728674232, 0.1270214647988628, 0.1307371933169002, 0.11761403804180182, 0.10477571553360025]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 3
# Output Difference :  0.8464174627132577
# ------------------------------------------------------
# outputList [0.10467083706529892, 0.12235937075176956, 0.1398648271988532, 0.15136827800913447, 0.1268276961260267, 0.13015823931389184, 0.1182511788595134, 0.1064995726755118]
# self.targetList [0, 0, 0, 0, 0, 0, 1, 0]
# Target Index :  6
# Output Index: 3
# Output Difference :  0.8486317219908656
# ------------------------------------------------------
# outputList [0.10329274981864628, 0.1222075333197167, 0.14090821893977906, 0.15294687502771778, 0.12699227340599265, 0.13055594234064835, 0.11781088191378705, 0.10528552523371214]
# self.targetList [0, 0, 0, 0, 1, 0, 0, 0]
# Target Index :  4
# Output Index: 3
# Output Difference :  0.8470531249722822
# ------------------------------------------------------
# outputList [0.10417106778336069, 0.12227883246705429, 0.1402564176665247, 0.15196372975570935, 0.1268998384517659, 0.13029659862832632, 0.11808591193908768, 0.10604760330817115]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 3
# Output Difference :  0.8480362702442906
# ------------------------------------------------------
# outputList [0.10372487718908743, 0.12225947213515892, 0.14055800026368998, 0.15245718744896852, 0.12697140813286373, 0.1304385120929638, 0.11794376451103555, 0.10564677822623211]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 3
# Output Difference :  0.8475428125510315
# ------------------------------------------------------
# outputList [0.10264567013700587, 0.12213486840057759, 0.14144724682919743, 0.1537017065594697, 0.12704227930346854, 0.13076928007565553, 0.11757680051065057, 0.10468214818397481]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 3
# Output Difference :  0.8462982934405303
# ------------------------------------------------------
# outputList [0.10380816769973802, 0.12225065895290799, 0.14052191141383225, 0.15235243840494336, 0.12693652034727787, 0.1303959476223935, 0.11797785853901087, 0.10575649701989613]
# self.targetList [0, 0, 0, 0, 0, 0, 0, 1]
# Target Index :  7
# Output Index: 3
# Output Difference :  0.8476475615950566
# ------------------------------------------------------
# outputList [0.10275776900415777, 0.12213203560686259, 0.14135768087247685, 0.15357321270456592, 0.12704248540756408, 0.13072072764487463, 0.11761874626155577, 0.10479734249794233]
# self.targetList [0, 0, 0, 0, 1, 0, 0, 0]
# Target Index :  4
# Output Index: 3
# Output Difference :  0.8464267872954341
# ------------------------------------------------------
# outputList [0.10343746825844825, 0.12221573357730493, 0.14082695984074922, 0.15278824580069134, 0.12696915182883037, 0.1305043897097886, 0.11785035520666964, 0.10540769577751763]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 3
# Output Difference :  0.8472117541993087
# ------------------------------------------------------
# outputList [0.10328253127669143, 0.12216286160779495, 0.1409643269340754, 0.15297515231448916, 0.12697436802717377, 0.13055407617347653, 0.11779597450771111, 0.10529070915858761]
# self.targetList [0, 1, 0, 0, 0, 0, 0, 0]
# Target Index :  1
# Output Index: 3
# Output Difference :  0.8470248476855109
# ------------------------------------------------------
# outputList [0.10273348415910105, 0.12212349629197049, 0.14139089510149402, 0.1536046457933249, 0.12703164987185486, 0.13071944516781067, 0.11762325978293785, 0.10477312383150618]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 3
# Output Difference :  0.8463953542066751
# ------------------------------------------------------
# outputList [0.10317046373381246, 0.12218464907166526, 0.14103198544752837, 0.15312147745900487, 0.126990865012355, 0.130608548876995, 0.11774821574251532, 0.10514379465612385]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 3
# Output Difference :  0.8468785225409952
# ------------------------------------------------------
# outputList [0.10398654816912564, 0.12228794985718751, 0.1403684808513224, 0.15216532824854187, 0.1269246888331883, 0.1303644776856004, 0.11803306885273261, 0.10586945750230141]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 3
# Output Difference :  0.8478346717514581
# ------------------------------------------------------
# outputList [0.10437220558525068, 0.12232916184273554, 0.14007085663716626, 0.15171053659955813, 0.1268823185032705, 0.13025687422125673, 0.11814121761759733, 0.1062368289931649]
# self.targetList [0, 1, 0, 0, 0, 0, 0, 0]
# Target Index :  1
# Output Index: 3
# Output Difference :  0.8482894634004419
# ------------------------------------------------------
# outputList [0.10277224275544762, 0.1221385287941674, 0.14135817131494435, 0.1535507213415798, 0.12701850737886566, 0.13070374399886595, 0.11765105682800286, 0.10480702758812623]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 3
# Output Difference :  0.8464492786584202
# ------------------------------------------------------
# outputList [0.10344854933161039, 0.12218215693905839, 0.14080227066869905, 0.15279089044656596, 0.1270119261814576, 0.13049959265737698, 0.11784088101677599, 0.10542373275845557]
# self.targetList [0, 0, 0, 0, 1, 0, 0, 0]
# Target Index :  4
# Output Index: 3
# Output Difference :  0.847209109553434
# ------------------------------------------------------
# outputList [0.10423159334521082, 0.12233026171225798, 0.14016285442689425, 0.15186860045397432, 0.12689835781346123, 0.13030280383448645, 0.11809678696167707, 0.10610874145203787]
# self.targetList [0, 0, 0, 0, 0, 0, 1, 0]
# Target Index :  6
# Output Index: 3
# Output Difference :  0.8481313995460257
# ------------------------------------------------------
# outputList [0.10316707208514228, 0.12218379821174184, 0.1410470061270028, 0.15310430472311867, 0.12698902357501604, 0.13058632235073608, 0.11774752361894847, 0.10517494930829373]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 3
# Output Difference :  0.8468956952768814
# ------------------------------------------------------
# outputList [0.10333107531601654, 0.12220484195604675, 0.14088225366853374, 0.15291474111413075, 0.12700155977305397, 0.13055843635382083, 0.11780436908803273, 0.10530272273036456]
# self.targetList [0, 0, 0, 0, 0, 0, 1, 0]
# Target Index :  6
# Output Index: 3
# Output Difference :  0.8470852588858693
# ------------------------------------------------------
# outputList [0.1043621452853888, 0.12233702995231646, 0.14008713726602082, 0.15172706867466546, 0.12686873013638694, 0.13025624111968256, 0.11813691853429555, 0.1062247290312433]
# self.targetList [1, 0, 0, 0, 0, 0, 0, 0]
# Target Index :  0
# Output Index: 3
# Output Difference :  0.8482729313253345
# ------------------------------------------------------
# outputList [0.10466748796121057, 0.12239615925819775, 0.13985469403442516, 0.15135641700754032, 0.1268142019159227, 0.1301623256015896, 0.11825035741747959, 0.10649835680363422]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 3
# Output Difference :  0.8486435829924597
# ------------------------------------------------------
# outputList [0.1032300564389755, 0.12220794310316059, 0.14098412063958923, 0.15303918501757222, 0.12697426989424482, 0.13057364497454405, 0.11779119629519547, 0.1051995836367181]
# self.targetList [0, 0, 0, 1, 0, 0, 0, 0]
# Target Index :  3
# Output Index: 3
# Output Difference :  0.8469608149824278
# ------------------------------------------------------
# outputList [0.10348334650911861, 0.12220828714287538, 0.14076149651955774, 0.15272488347492966, 0.1270044737851892, 0.13047972940831443, 0.11787184119705274, 0.1054659419629622]
# self.targetList [0, 0, 0, 0, 1, 0, 0, 0]
# Target Index :  4
# Output Index: 3
# Output Difference :  0.8472751165250704
# ------------------------------------------------------
# outputList [0.10298175461117773, 0.12217170464386545, 0.14116431543158617, 0.15328989191601539, 0.12702381937972382, 0.13063275446144404, 0.11771624223526957, 0.10501951732091785]
# self.targetList [0, 0, 0, 0, 0, 0, 1, 0]
# Target Index :  6
# Output Index: 3
# Output Difference :  0.8467101080839846
# ------------------------------------------------------
# outputList [0.10437919221581766, 0.12236297842475694, 0.14008404722406614, 0.15169162130428337, 0.12684310980078026, 0.13023424692219945, 0.11815992956644437, 0.10624487454165178]
# self.targetList [0, 0, 0, 0, 1, 0, 0, 0]
# Target Index :  4
# Output Index: 3
# Output Difference :  0.8483083786957166
# ------------------------------------------------------
# outputList [0.10311686878172743, 0.12215940776975541, 0.14107209322896042, 0.1531485374348749, 0.12702457310920634, 0.1305921915581798, 0.11775440519859574, 0.10513192291870006]
# self.targetList [0, 0, 0, 0, 0, 0, 1, 0]
# Target Index :  6
# Output Index: 3
# Output Difference :  0.8468514625651251
# ------------------------------------------------------
# outputList [0.10389111813791498, 0.12226060800788549, 0.14050755257355824, 0.152298266529626, 0.12687495891684056, 0.13038875844819497, 0.11795965103067967, 0.10581908635530009]
# self.targetList [0, 0, 0, 0, 1, 0, 0, 0]
# Target Index :  4
# Output Index: 3
# Output Difference :  0.847701733470374
# ------------------------------------------------------
# outputList [0.10261566628623361, 0.12210029151640377, 0.14143576719349046, 0.15370482737982966, 0.12709917063406956, 0.13073741065980063, 0.11760290521521095, 0.10470396111496136]
# self.targetList [0, 0, 0, 0, 0, 1, 0, 0]
# Target Index :  5
# Output Index: 3
# Output Difference :  0.8462951726201704
# ------------------------------------------------------
# outputList [0.10390758664648435, 0.12223182834262285, 0.14047475408937088, 0.15227821478695316, 0.12693208851277965, 0.13037411133437285, 0.11798305784545163, 0.10581835844196466]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 3
# Output Difference :  0.8477217852130469
# ------------------------------------------------------
# outputList [0.10380209520425909, 0.1222602791124867, 0.14054577661520984, 0.152396813330626, 0.1269172463056021, 0.1304204060533248, 0.11794276690908691, 0.10571461646940444]
# self.targetList [0, 0, 1, 0, 0, 0, 0, 0]
# Target Index :  2
# Output Index: 3
# Output Difference :  0.8476031866693741
# rightAnswerCount :  19 /Out of :  80

# %%
values, count = np.unique(g.trainDf['label'], return_counts=True)
print(values, count)
# Out:
# [0 1 2 3 4 5 6 7] [ 2  9 16 19 11 12  8  3]
